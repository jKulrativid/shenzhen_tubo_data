# %%
from __future__ import print_function, division

import torch
from torchvision import transforms, utils
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader
from skimage import io, transform

import warnings
warnings.filterwarnings("ignore")

plt.ion()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/shenzhen_tubeculosis/shenzhen_metadata.csv')

# %%
df.head()
# Out:
#             study_id     sex  age findings
# 0  CHNCXR_0001_0.png    Male   45   normal
# 1  CHNCXR_0002_0.png    Male   63   normal
# 2  CHNCXR_0003_0.png  Female   48   normal
# 3  CHNCXR_0004_0.png    Male   58   normal
# 4  CHNCXR_0005_0.png    Male   28   normal

# %%
n = 20
img_name = df.iloc[:, 0]
img_name.head()
# Out:
# 0    CHNCXR_0001_0.png
# 1    CHNCXR_0002_0.png
# 2    CHNCXR_0003_0.png
# 3    CHNCXR_0004_0.png
# 4    CHNCXR_0005_0.png
# Name: study_id, dtype: object

# %%
class TubeDataset(Dataset):

    def __init__(self, csv_file, root_dir, transform=None):
        self.csv_file = csv_file
        self.root_dir = root_dir
        self.transform = transform

    def __len__(self):
        return len(self.csv_file)

    def __getitem__(self, idx):

        if torch.is_tensor(idx):
            idx = idx.to_list()

        img_name = os.path.join(self.root_dir, self.csv_file['study_id'][idx])
        image = io.imread(img_name)
        sample = {'image': image}

        if self.transform:
            sample = self.transform(sample)

        return sample

# %%
tube_dataset = TubeDataset(csv_file=df, root_dir='/content/drive/MyDrive/shenzhen_tubeculosis/images/images')
fig = plt.figure()

n_show = 4
for i in range(n_show):
    sample = tube_dataset[i]
    
    print(i, sample['image'].shape)
    ax = plt.subplot(1, 4, i+1)
    plt.tight_layout()
    ax.set_title('Sample #{}'.format(i+1))
    ax.axis('off')
    plt.imshow(sample['image'])

plt.show()
# Out:
# 0 (2919, 3000)
# 1 (2951, 3000)
# 2 (2945, 2987)
# 3 (2933, 3000)

# %%
class Rescale(object):
    
    def __init__(self, output_size):
        assert isinstance(output_size, (int, tuple))  # must be int or tuple
        self.output_size = output_size

    def __call__(self, sample):
        image = sample['image']

        h, w = image.shape[:2]
        if isinstance(self.output_size, int):
            if h > w:
                new_h, new_w = self.output_size * h / w, self.output_size
            else :
                new_h, new_w = self.output_size, self.output_size * w / h
        else:
            new_h, new_w = self.output_size

        new_h, new_w = int(new_h), int(new_w)
        img = transform.resize(image, (new_h, new_w))

        return {'image': img}
    
class RandomCrop(object):

    def __init__(self, output_size):
        
        assert isinstance(output_size, (int, tuple))
        if isinstance(output_size, int):
            self.output_size = (output_size, output_size)
        else:
            self.output_size = output_size
        
    def __call__(self, sample):
        
        image = sample['image']
        
        h, w = image.shape[:2]
        new_h, new_w = self.output_size

        top = np.random.randint(0, h - new_h)
        left = np.random.randint(0, w - new_w)

        image = image[top:top+new_h,
                      left:left+new_w]

        return {'image': image}

class ToTensor(object):

    def __call__(self, sample):

        image = sample['image']
        image = image.transpose((2, 0, 1))
        return {'image': image}

# %%
scale = Rescale(256)
crop = RandomCrop(2500)
composed = transforms.Compose([Rescale(256), RandomCrop(220)])

# %%
fig = plt.figure()
sample = tube_dataset[23]

for i, tsfrm in enumerate([scale, crop, composed]):
    transformed_sample = tsfrm(sample)

    ax = plt.subplot(1, 3, i+1)
    plt.tight_layout()
    ax.set_title(type(tsfrm).__name__)
    plt.imshow(transformed_sample['image'])

plt.show()

# %%
transformed_dataset = TubeDataset(csv_file=df,
                                  root_dir='/content/drive/MyDrive/shenzhen_tubeculosis/images/images',
                                  transform=transforms.Compose([Rescale(256), RandomCrop(220)]))
